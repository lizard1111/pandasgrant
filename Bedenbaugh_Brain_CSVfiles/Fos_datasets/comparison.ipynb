# %%
import os
import pandas as pd

# Set the directory containing the CSV files
directory = '.'

# Loop through the files in the directory and print the filename  if it ends with .csv
for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        print(f'Found CSV: {filename}')
# Out:
# Found CSV: Male2_FastRefeed_Fos_output.csv
# Found CSV: FemaleRR_Fed_Fos_output.csv
# Found CSV: Female1_Restraint_Fos_output.csv
# Found CSV: MaleL_FastRefeed_Fos_output.csv
# Found CSV: FemaleB_Restraint_Fos_output.csv
# Found CSV: MaleR_Fed_Fos_output.csv

# %%
filenames = [f for f in os.listdir('.') if f.endswith('.csv')]

# Loop through each file and perform checks
for filename in filenames:
    # Read in the CSV file
    df = pd.read_csv(filename)
    
    # Check number of rows and columns
    if df.shape != (1678, 8):
        print(f"Error: {filename} has {df.shape[0]} rows and {df.shape[1]} columns.")
    
    # Check for missing values
    if df.isnull().values.any():
        print(f"Error: {filename} contains missing values.")
        
    # Check data types
    if df.dtypes.any() != float:
        print(f"Error: {filename} contains non-numeric data.")
    
    # Look for anomalies or outliers in the data
    # This would depend on the specifics of your data and the scientific question you are trying to answer.
# Out:
# Error: Male2_FastRefeed_Fos_output.csv contains non-numeric data.
# Error: FemaleRR_Fed_Fos_output.csv contains non-numeric data.
# Error: Female1_Restraint_Fos_output.csv contains non-numeric data.
# Error: MaleL_FastRefeed_Fos_output.csv contains non-numeric data.
# Error: FemaleB_Restraint_Fos_output.csv contains non-numeric data.
# Error: MaleR_Fed_Fos_output.csv contains non-numeric data.

# %%
# Create empty lists to store the dataframes
fed_dfs = []
fast_refeed_dfs = []
restraint_dfs = []

# Loop through each file in the current directory
for file in os.listdir():
    # Check if the file is a CSV and contains "Fos_output"
    if file.endswith(".csv") and "Fos_output" in file:
        # Read the CSV into a dataframe
        df = pd.read_csv(file)
        # Determine which group the file belongs to based on the file name
        if "Fed" in file:
            fed_dfs.append(df)
        elif "FastRefeed" in file:
            fast_refeed_dfs.append(df)
        elif "Restraint" in file:
            restraint_dfs.append(df)

# Combine the dataframes for each group into a single dataframe
fed_df = pd.concat(fed_dfs)
fast_refeed_df = pd.concat(fast_refeed_dfs)
restraint_df = pd.concat(restraint_dfs)

# %%
fed_df.describe()
# Out:
#                  id  parent_structure_id        depth         count
# count   3356.000000          3356.000000  3356.000000  3.356000e+03  \
# mean    5616.380215          5589.783075     6.373659  1.881792e+04
# std     5015.855923          5016.992858     1.649227  1.433884e+05
# min       -1.000000            -2.000000    -1.000000  0.000000e+00
# 25%      649.000000           641.000000     5.000000  2.580000e+02
# 50%     5651.500000          1297.000000     6.000000  1.233500e+03
# 75%    10650.000000         10642.000000     8.000000  4.525500e+03
# max    11303.000000         11301.000000     9.000000  3.091451e+06
#
#        volume (mm^3)  density (cells/mm^3)
# count    3356.000000           3356.000000
# mean        2.611701           7601.208832
# std        22.158519           7359.816890
# min         0.000016              0.000000
# 25%         0.070547           2517.517202
# 50%         0.234828           5365.064036
# 75%         0.681484          10283.213187
# max       699.556516          64000.000000

# %%
fast_refeed_df.describe()
# Out:
#                  id  parent_structure_id        depth         count
# count   3356.000000          3356.000000  3356.000000  3.356000e+03  \
# mean    5616.380215          5589.783075     6.373659  3.172551e+04
# std     5015.855923          5016.992858     1.649227  2.280956e+05
# min       -1.000000            -2.000000    -1.000000  0.000000e+00
# 25%      649.000000           641.000000     5.000000  5.660000e+02
# 50%     5651.500000          1297.000000     6.000000  2.506000e+03
# 75%    10650.000000         10642.000000     8.000000  8.360500e+03
# max    11303.000000         11301.000000     9.000000  4.088794e+06
#
#        volume (mm^3)  density (cells/mm^3)
# count    3356.000000           3356.000000
# mean        2.611701          13666.184148
# std        22.158519          10782.788418
# min         0.000016              0.000000
# 25%         0.070547           5731.217193
# 50%         0.234828          10450.774332
# 75%         0.681484          19343.121480
# max       699.556516          84900.855242

# %%
restraint_df.describe()
# Out:
#                  id  parent_structure_id        depth         count
# count   3356.000000          3356.000000  3356.000000  3.356000e+03  \
# mean    5616.380215          5589.783075     6.373659  2.819599e+04
# std     5015.855923          5016.992858     1.649227  2.041469e+05
# min       -1.000000            -2.000000    -1.000000  0.000000e+00
# 25%      649.000000           641.000000     5.000000  5.737500e+02
# 50%     5651.500000          1297.000000     6.000000  2.522000e+03
# 75%    10650.000000         10642.000000     8.000000  7.574000e+03
# max    11303.000000         11301.000000     9.000000  3.744577e+06
#
#        volume (mm^3)  density (cells/mm^3)
# count    3356.000000           3356.000000
# mean        2.611701          13372.811250
# std        22.158519          10747.139804
# min         0.000016              0.000000
# 25%         0.070547           5388.465109
# 50%         0.234828          10393.987007
# 75%         0.681484          18942.457420
# max       699.556516          96431.144519

# %%
pd.options.display.max_rows = None
pd.options.display.float_format = '{:,.0f}'.format

restraint_df.describe()
fed_df.describe()
# Out:
#           id  parent_structure_id  depth     count  volume (mm^3)
# count  3,356                3,356  3,356     3,356          3,356  \
# mean   5,616                5,590      6    18,818              3
# std    5,016                5,017      2   143,388             22
# min       -1                   -2     -1         0              0
# 25%      649                  641      5       258              0
# 50%    5,652                1,297      6     1,234              0
# 75%   10,650               10,642      8     4,526              1
# max   11,303               11,301      9 3,091,451            700
#
#        density (cells/mm^3)
# count                 3,356
# mean                  7,601
# std                   7,360
# min                       0
# 25%                   2,518
# 50%                   5,365
# 75%                  10,283
# max                  64,000

# %%
import pandas as pd

# Merge with the structure dataframe to add the name and acronym columns
# fed_df = pd.merge(fed_df, structure_df[['id', 'name', 'acronym']], on='id')
# fast_refeed_df = pd.merge(fastrefeed_df, structure_df[['id', 'name', 'acronym']], on='id')
# restraint_df = pd.merge(restraint_df, structure_df[['id', 'name', 'acronym']], on='id')

# Sort the dataframes by count and density values and select top 20 rows
fed_top_20 = fed_df.sort_values(by=['count', 'density (cells/mm^3)'], ascending=False).head(20)
fastrefeed_top_20 = fastrefeed_df.sort_values(by=['count', 'density (cells/mm^3)'], ascending=False).head(20)
restraint_top_20 = restraint_df.sort_values(by=['count', 'density (cells/mm^3)'], ascending=False).head(20)

# Format the dataframes to show integers with commas for thousands separators
fed_top_20 = fed_top_20.applymap(lambda x: "{:,}".format(int(x)))
fastrefeed_top_20 = fastrefeed_top_20.applymap(lambda x: "{:,}".format(int(x)))
restraint_top_20 = restraint_top_20.applymap(lambda x: "{:,}".format(int(x)))
`X`
# Display the top 20 areas for each group
print("Top 20 areas for Fed group:")
print(fed_top_20[['id', 'name', 'acronym', 'count', 'density (cells/mm^3)']])
print()

print("Top 20 areas for FastRefeed group:")
print(fastrefeed_top_20[['id', 'name', 'acronym', 'count', 'density (cells/mm^3)']])
print()

print("Top 20 areas for Restraint group:")
print(restraint_top_20[['id', 'name', 'acronym', 'count', 'density (cells/mm^3)']])
# Out:
# Top 20 areas for Fed group:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 20
#      18 # Display the top 20 areas for each group
#      19 print("Top 20 areas for Fed group:")
# ---> 20 print(fed_top_20[['id', 'name', 'acronym', 'count', 'density (cells/mm^3)']])
#      21 print()
#      23 print("Top 20 areas for FastRefeed group:")
#
# File ~/opt/anaconda3/envs/pandas/lib/python3.10/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~/opt/anaconda3/envs/pandas/lib/python3.10/site-packages/pandas/core/indexes/base.py:5876, in Index._get_indexer_strict(self, key, axis_name)
#    5873 else:
#    5874     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5876 self._raise_if_missing(keyarr, indexer, axis_name)
#    5878 keyarr = self.take(indexer)
#    5879 if isinstance(key, Index):
#    5880     # GH 42790 - Preserve name from an Index
#
# File ~/opt/anaconda3/envs/pandas/lib/python3.10/site-packages/pandas/core/indexes/base.py:5938, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5935     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5937 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5938 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['id', 'name', 'acronym'] not in index"

# %%
import pandas as pd
import glob

# Get a list of all CSV files in the current directory
csv_files = glob.glob('*.csv')

# Create empty data frames for each group
fed_df = pd.DataFrame()
fastrefeed_df = pd.DataFrame()
restraint_df = pd.DataFrame()

# Iterate through the CSV files
for file in csv_files:
    # Read in the data
    df = pd.read_csv(file)
    
    # Select only the relevant columns
    df = df[['count', 'density (cells/mm^3)']]
    
    # Determine which group the data belongs to and concatenate it accordingly
    if 'Fed' in file:
        fed_df = pd.concat([fed_df, df], axis=0)
    elif 'FastRefeed' in file:
        fastrefeed_df = pd.concat([fastrefeed_df, df], axis=0)
    elif 'Restraint' in file:
        restraint_df = pd.concat([restraint_df, df], axis=0)
    else:
        print(f"Warning: {file} does not match any group.")

# Take the mean of each group
fed_mean = fed_df.mean()
fastrefeed_mean = fastrefeed_df.mean()
restraint_mean = restraint_df.mean()

# Print the means
print("Mean count and density for Fed group:\n", fed_mean)
print("Mean count and density for FastRefeed group:\n", fastrefeed_mean)
print("Mean count and density for Restraint group:\n", restraint_mean)
# Out:
# Mean count and density for Fed group:
#  count                  18,818
# density (cells/mm^3)    7,601
# dtype: float64
# Mean count and density for FastRefeed group:
#  count                  31,726
# density (cells/mm^3)   13,666
# dtype: float64
# Mean count and density for Restraint group:
#  count                  28,196
# density (cells/mm^3)   13,373
# dtype: float64

# %%
import pandas as pd

# load all six CSV files into a list of DataFrames
dfs = []
for file in os.listdir():
    if file.endswith('.csv'):
        df = pd.read_csv(file)
        dfs.append(df)

# combine the six DataFrames into one using concat
combined_df = pd.concat(dfs)

# group the combined DataFrame by 'name' and 'acronym', and calculate the mean for 'count' and 'density'
averaged_df = combined_df.groupby(['name', 'acronym'])[['count', 'density (cells/mm^3)']].mean()


# format the DataFrame to show integers with commas for thousands separators
averaged_df = averaged_df.applymap(lambda x: "{:,}".format(int(x)))

# display the averaged DataFrame
pd.options.display.max_rows = None
print(averaged_df)
# Out:
#                                                                        count
# name                                               acronym
# background                                         bkd               879,520  \
# left Abducens nucleus                              VI-L                   84
# left Accessory facial motor nucleus                ACVII-L                 7
# left Accessory olfactory bulb                      AOB-L               8,108
# left Accessory olfactory bulb, glomerular layer    AOBgl-L               691
# left Accessory olfactory bulb, granular layer      AOBgr-L             5,005
# left Accessory olfactory bulb, mitral layer        AOBmi-L             2,411
# left Accessory supraoptic group                    ASO-L                  69
# left Accessory trigeminal nucleus                  Acs5-L                 14
# left Agranular insular area                        AI-L               65,910
# left Agranular insular area, dorsal part           AId-L              31,282
# left Agranular insular area, dorsal part, layer 1  AId1-L              3,042
# left Agranular insular area, dorsal part, layer... AId2/3-L            7,745
# left Agranular insular area, dorsal part, layer 5  AId5-L             14,204
# left Agranular insular area, dorsal part, layer 6a AId6a-L             6,042
# left Agranular insular area, dorsal part, layer 6b AId6b-L               248
# left Agranular insular area, posterior part        AIp-L              18,823
# left Agranular insular area, posterior part, la... AIp1-L              3,130
# left Agranular insular area, posterior part, la... AIp2/3-L            5,977
# left Agranular insular area, posterior part, la... AIp5-L              6,298
# left Agranular insular area, posterior part, la... AIp6a-L             3,288
# left Agranular insular area, posterior part, la... AIp6b-L               129
# left Agranular insular area, ventral part          AIv-L              15,803
# left Agranular insular area, ventral part, layer 1 AIv1-L              2,183
# left Agranular insular area, ventral part, laye... AIv2/3-L            5,282
# left Agranular insular area, ventral part, layer 5 AIv5-L              7,068
# left Agranular insular area, ventral part, laye... AIv6a-L             1,255
# left Agranular insular area, ventral part, laye... AIv6b-L                14
# left Ammon's horn                                  CA-L               43,645
# left Ansiform lobule                               AN-L               38,103
# left Anterior amygdalar area                       AAA-L               2,113
# left Anterior area                                 VISa-L             16,020
# left Anterior area, layer 1                        VISa1-L             1,648
# left Anterior area, layer 2/3                      VISa2/3-L           5,051
# left Anterior area, layer 4                        VISa4-L             2,612
# left Anterior area, layer 5                        VISa5-L             4,032
# left Anterior area, layer 6a                       VISa6a-L            2,279
# left Anterior area, layer 6b                       VISa6b-L              395
# left Anterior cingulate area                       ACA-L              55,097
# left Anterior cingulate area, dorsal part          ACAd-L             28,812
# left Anterior cingulate area, dorsal part, layer 1 ACAd1-L             3,334
# left Anterior cingulate area, dorsal part, laye... ACAd2/3-L           7,694
# left Anterior cingulate area, dorsal part, layer 5 ACAd5-L            12,600
# left Anterior cingulate area, dorsal part, laye... ACAd6a-L            5,054
# left Anterior cingulate area, dorsal part, laye... ACAd6b-L              129
# left Anterior cingulate area, ventral part         ACAv-L             26,285
# left Anterior cingulate area, ventral part, 6a     ACAv6a-L            2,930
# left Anterior cingulate area, ventral part, 6b     ACAv6b-L              359
# left Anterior cingulate area, ventral part, lay... ACAv1-L             3,198
# left Anterior cingulate area, ventral part, lay... ACAv2/3-L           8,136
# left Anterior cingulate area, ventral part, lay... ACAv5-L            11,660
# left Anterior group of the dorsal thalamus         ATN-L               7,086
# left Anterior hypothalamic nucleus                 AHN-L               3,959
# left Anterior olfactory nucleus                    AON-L              53,804
# left Anterior pretectal nucleus                    APN-L               2,215
# left Anterior tegmental nucleus                    AT-L                   34
# left Anterodorsal nucleus                          AD-L                  506
# left Anterodorsal preoptic nucleus                 ADP-L               1,105
# left Anterolateral visual area                     VISal-L             9,811
# left Anterolateral visual area, layer 1            VISal1-L            1,026
# left Anterolateral visual area, layer 2/3          VISal2/3-L          2,372
# left Anterolateral visual area, layer 4            VISal4-L            2,005
# left Anterolateral visual area, layer 5            VISal5-L            2,693
# left Anterolateral visual area, layer 6a           VISal6a-L           1,408
# left Anterolateral visual area, layer 6b           VISal6b-L             306
# left Anteromedial nucleus                          AM-L                2,123
# left Anteromedial nucleus, dorsal part             AMd-L               1,270
# left Anteromedial nucleus, ventral part            AMv-L                 852
# left Anteromedial visual area                      VISam-L             8,602
# left Anteromedial visual area, layer 1             VISam1-L              944
# left Anteromedial visual area, layer 2/3           VISam2/3-L          2,609
# left Anteromedial visual area, layer 4             VISam4-L              915
# left Anteromedial visual area, layer 5             VISam5-L            2,464
# left Anteromedial visual area, layer 6a            VISam6a-L           1,395
# left Anteromedial visual area, layer 6b            VISam6b-L             274
# left Anteroventral nucleus of thalamus             AV-L                2,028
# left Anteroventral periventricular nucleus         AVPV-L              2,443
# left Anteroventral preoptic nucleus                AVP-L                 568
# left Arcuate hypothalamic nucleus                  ARH-L               2,743
# left Area postrema                                 AP-L                  597
# left Area prostriata                               APr-L               1,569
# left Auditory areas                                AUD-L              63,712
# left Barrington's nucleus                          B-L                   153
# left Basic cell groups and regions                 grey-L          3,065,414
# left Basolateral amygdalar nucleus                 BLA-L              12,596
# left Basolateral amygdalar nucleus, anterior part  BLAa-L              5,789
# left Basolateral amygdalar nucleus, posterior part BLAp-L              4,198
# left Basolateral amygdalar nucleus, ventral part   BLAv-L              2,608
# left Basomedial amygdalar nucleus                  BMA-L               8,546
# left Basomedial amygdalar nucleus, anterior part   BMAa-L              4,793
# left Basomedial amygdalar nucleus, posterior part  BMAp-L              3,752
# left Bed nuclei of the stria terminalis            BST-L               6,821
# left Bed nucleus of the accessory olfactory tract  BA-L                  319
# left Bed nucleus of the anterior commissure        BAC-L                  41
# left Brain stem                                    BS-L              430,166
# left Caudoputamen                                  CP-L               61,440
# left Central amygdalar nucleus                     CEA-L               8,214
# left Central amygdalar nucleus, capsular part      CEAc-L              1,860
# left Central amygdalar nucleus, lateral part       CEAl-L              2,422
# left Central amygdalar nucleus, medial part        CEAm-L              3,931
# left Central lateral nucleus of the thalamus       CL-L                  922
# left Central linear nucleus raphe                  CLI-L                 159
# left Central lobule                                CENT-L              8,132
# left Central medial nucleus of the thalamus        CM-L                1,865
# left Cerebellar cortex                             CBX-L             199,507
# left Cerebellar nuclei                             CBN-L                 848
# left Cerebellum                                    CB-L              203,084
# left Cerebral cortex                               CTX-L           2,232,619
# left Cerebral nuclei                               CNU-L             199,544
# left Cerebrum                                      CH-L            2,432,163
# left Claustrum                                     CLA-L               4,244
# left Cochlear nuclei                               CN-L                5,431
# left Copula pyramidis                              COPY-L              8,724
# left Cortical amygdalar area                       COA-L              26,684
# left Cortical amygdalar area, anterior part        COAa-L              7,399
# left Cortical amygdalar area, posterior part       COAp-L             19,285
# left Cortical amygdalar area, posterior part, l... COApl-L             8,518
# left Cortical amygdalar area, posterior part, m... COApm-L            10,766
# left Cortical plate                                CTXpl-L         2,179,434
# left Cortical subplate                             CTXsp-L            53,184
# left Crus 1                                        ANcr1-L            24,342
# left Crus 2                                        ANcr2-L            13,760
# left Culmen                                        CUL-L              16,144
# left Cuneate nucleus                               CU-L                1,152
# left Cuneiform nucleus                             CUN-L                 773
# left Declive (VI)                                  DEC-L              15,808
# left Dentate gyrus                                 DG-L               13,531
# left Dentate gyrus, granule cell layer             DG-sg-L             3,597
# left Dentate gyrus, molecular layer                DG-mo-L             7,664
# left Dentate gyrus, polymorph layer                DG-po-L             2,269
# left Dentate nucleus                               DN-L                   68
# left Diagonal band nucleus                         NDB-L               2,821
# left Dorsal auditory area                          AUDd-L             12,997
# left Dorsal auditory area, layer 1                 AUDd1-L             1,644
# left Dorsal auditory area, layer 2/3               AUDd2/3-L           2,808
# left Dorsal auditory area, layer 4                 AUDd4-L             2,154
# left Dorsal auditory area, layer 5                 AUDd5-L             4,183
# left Dorsal auditory area, layer 6a                AUDd6a-L            1,776
# left Dorsal auditory area, layer 6b                AUDd6b-L              430
# left Dorsal cochlear nucleus                       DCO-L               2,499
# left Dorsal column nuclei                          DCN-L               1,610
# left Dorsal motor nucleus of the vagus nerve       DMX-L               1,568
# left Dorsal nucleus raphe                          DR-L                  733
# left Dorsal part of the lateral geniculate complex LGd-L               2,177
# left Dorsal part of the lateral geniculate comp... LGd-co-L            1,491
# left Dorsal part of the lateral geniculate comp... LGd-ip-L              173
# left Dorsal part of the lateral geniculate comp... LGd-sh-L              512
# left Dorsal peduncular area                        DP-L                4,415
# left Dorsal premammillary nucleus                  PMd-L                 423
# left Dorsal tegmental nucleus                      DTN-L                 299
# left Dorsal terminal nucleus of the accessory o... DT-L                   42
# left Dorsomedial nucleus of the hypothalamus       DMH-L               4,259
# left Ectorhinal area                               ECT-L              14,470
# left Ectorhinal area/Layer 1                       ECT1-L              2,422
# left Ectorhinal area/Layer 2/3                     ECT2/3-L            4,217
# left Ectorhinal area/Layer 5                       ECT5-L              4,305
# left Ectorhinal area/Layer 6a                      ECT6a-L             3,139
# left Ectorhinal area/Layer 6b                      ECT6b-L               385
# left Edinger-Westphal nucleus                      EW-L                  177
# left Endopiriform nucleus                          EP-L               15,346
# left Endopiriform nucleus, dorsal part             EPd-L              10,481
# left Endopiriform nucleus, ventral part            EPv-L               4,865
# left Entorhinal area                               ENT-L              93,874
# left Entorhinal area, lateral part                 ENTl-L             57,208
# left Entorhinal area, lateral part, layer 1        ENTl1-L             9,235
# left Entorhinal area, lateral part, layer 2        ENTl2-L            18,077
# left Entorhinal area, lateral part, layer 3        ENTl3-L            11,611
# left Entorhinal area, lateral part, layer 5        ENTl5-L            10,786
# left Entorhinal area, lateral part, layer 6a       ENTl6a-L            7,498
# left Entorhinal area, medial part, dorsal zone     ENTm-L             36,665
# left Entorhinal area, medial part, dorsal zone,... ENTm1-L             8,372
# left Entorhinal area, medial part, dorsal zone,... ENTm2-L             8,846
# left Entorhinal area, medial part, dorsal zone,... ENTm3-L             7,900
# left Entorhinal area, medial part, dorsal zone,... ENTm5-L             7,080
# left Entorhinal area, medial part, dorsal zone,... ENTm6-L             4,465
# left Epithalamus                                   EPI-L               2,374
# left Ethmoid nucleus of the thalamus               Eth-L                 244
# left External cuneate nucleus                      ECU-L               1,249
# left Facial motor nucleus                          VII-L               1,861
# left Fasciola cinerea                              FC-L                  299
# left Fastigial nucleus                             FN-L                  437
# left Field CA1                                     CA1-L              29,971
# left Field CA2                                     CA2-L                 904
# left Field CA3                                     CA3-L              12,770
# left Fields of Forel                               FF-L                  536
# left Flocculus                                     FL-L               12,905
# left Folium-tuber vermis (VII)                     FOTU-L              4,725
# left Frontal pole, cerebral cortex                 FRP-L               8,066
# left Frontal pole, layer 1                         FRP1-L              1,661
# left Frontal pole, layer 2/3                       FRP2/3-L            1,920
# left Frontal pole, layer 5                         FRP5-L              3,612
# left Frontal pole, layer 6a                        FRP6a-L               866
# left Frontal pole, layer 6b                        FRP6b-L                 6
# left Fundus of striatum                            FS-L                1,573
# left Geniculate group, dorsal thalamus             GENd-L              4,362
# left Geniculate group, ventral thalamus            GENv-L              3,259
# left Gigantocellular reticular nucleus             GRN-L               3,160
# left Globus pallidus, external segment             GPe-L               2,122
# left Globus pallidus, internal segment             GPi-L                 380
# left Gracile nucleus                               GR-L                  458
# left Gustatory areas                               GU-L               20,476
# left Gustatory areas, layer 1                      GU1-L               2,195
# left Gustatory areas, layer 2/3                    GU2/3-L             5,255
# left Gustatory areas, layer 4                      GU4-L               2,018
# left Gustatory areas, layer 5                      GU5-L               7,104
# left Gustatory areas, layer 6a                     GU6a-L              3,745
# left Gustatory areas, layer 6b                     GU6b-L                158
# left Hemispheric regions                           HEM-L             124,909
# left Hindbrain                                     HB-L              149,016
# left Hippocampal formation                         HPF-L             194,448
# left Hippocampal region                            HIP-L              58,056
# left Hippocampo-amygdalar transition area          HATA-L              4,136
# left Hypoglossal nucleus                           XII-L               1,352
# left Hypothalamic lateral zone                     LZ-L               18,943
# left Hypothalamic medial zone                      MEZ-L              20,965
# left Hypothalamus                                  HY-L               86,413
# left Induseum griseum                              IG-L                  580
# left Inferior colliculus                           IC-L               32,242
# left Inferior colliculus, central nucleus          ICc-L               8,401
# left Inferior colliculus, dorsal nucleus           ICd-L              12,781
# left Inferior colliculus, external nucleus         ICe-L              11,059
# left Inferior olivary complex                      IO-L                1,803
# left Inferior salivatory nucleus                   ISN-L                  32
# left Infracerebellar nucleus                       ICB-L                  15
# left Infralimbic area                              ILA-L               7,707
# left Infralimbic area, layer 1                     ILA1-L                449
# left Infralimbic area, layer 2/3                   ILA2/3-L            1,202
# left Infralimbic area, layer 5                     ILA5-L              4,114
# left Infralimbic area, layer 6a                    ILA6a-L             1,917
# left Infralimbic area, layer 6b                    ILA6b-L                22
# left Interanterodorsal nucleus of the thalamus     IAD-L                 823
# left Interanteromedial nucleus of the thalamus     IAM-L                 480
# left Interbrain                                    IB-L              151,033
# left Intercalated amygdalar nucleus                IA-L                1,325
# left Interfascicular nucleus raphe                 IF-L                  243
# left Intergeniculate leaflet of the lateral gen... IGL-L                 585
# left Intermediate geniculate nucleus               IntG-L                117
# left Intermediate reticular nucleus                IRN-L               6,547
# left Intermediodorsal nucleus of the thalamus      IMD-L               1,518
# left Interpeduncular nucleus                       IPN-L               1,149
# left Interpeduncular nucleus, apical               IPA-L                  86
# left Interpeduncular nucleus, caudal               IPC-L                 212
# left Interpeduncular nucleus, dorsolateral         IPDL-L                 74
# left Interpeduncular nucleus, dorsomedial          IPDM-L                 82
# left Interpeduncular nucleus, intermediate         IPI-L                  84
# left Interpeduncular nucleus, lateral              IPL-L                 201
# left Interpeduncular nucleus, rostral              IPR-L                 332
# left Interpeduncular nucleus, rostrolateral        IPRL-L                 52
# left Interposed nucleus                            IP-L                  293
# left Interstitial nucleus of Cajal                 INC-L                 177
# left Intertrigeminal nucleus                       I5-L                   39
# left Intralaminar nuclei of the dorsal thalamus    ILM-L               5,627
# left Isocortex                                     Isocortex-L     1,294,182
# left Koelliker-Fuse subnucleus                     KF-L                  433
# left Lateral amygdalar nucleus                     LA-L                4,404
# left Lateral dorsal nucleus of thalamus            LD-L                1,124
# left Lateral group of the dorsal thalamus          LAT-L               4,824
# left Lateral habenula                              LH-L                  982
# left Lateral hypothalamic area                     LHA-L               7,392
# left Lateral mammillary nucleus                    LM-L                  295
# left Lateral posterior nucleus of the thalamus     LP-L                2,050
# left Lateral preoptic area                         LPO-L               1,703
# left Lateral reticular nucleus                     LRN-L               3,030
# left Lateral reticular nucleus, magnocellular part LRNm-L              2,893
# left Lateral reticular nucleus, parvicellular part LRNp-L                137
# left Lateral septal complex                        LSX-L              27,023
# left Lateral septal nucleus                        LS-L               25,321
# left Lateral septal nucleus, caudal (caudodorsa... LSc-L               3,900
# left Lateral septal nucleus, rostral (rostroven... LSr-L              13,929
# left Lateral septal nucleus, ventral part          LSv-L               7,491
# left Lateral terminal nucleus of the accessory ... LT-L                   40
# left Lateral vestibular nucleus                    LAV-L                 140
# left Lateral visual area                           VISl-L             19,086
# left Lateral visual area, layer 1                  VISl1-L             2,406
# left Lateral visual area, layer 2/3                VISl2/3-L           5,778
# left Lateral visual area, layer 4                  VISl4-L             3,706
# left Lateral visual area, layer 5                  VISl5-L             4,245
# left Lateral visual area, layer 6a                 VISl6a-L            2,598
# left Lateral visual area, layer 6b                 VISl6b-L              351
# left Laterodorsal tegmental nucleus                LDT-L               1,172
# left Laterointermediate area                       VISli-L             7,007
# left Laterointermediate area, layer 1              VISli1-L              932
# left Laterointermediate area, layer 2/3            VISli2/3-L          2,003
# left Laterointermediate area, layer 4              VISli4-L            1,045
# left Laterointermediate area, layer 5              VISli5-L            1,879
# left Laterointermediate area, layer 6a             VISli6a-L             993
# left Laterointermediate area, layer 6b             VISli6b-L             153
# left Linear nucleus of the medulla                 LIN-L                 230
# left Lingula (I)                                   LING-L                551
# left Lobule II                                     CENT2-L             2,684
# left Lobule III                                    CENT3-L             5,448
# left Lobules IV-V                                  CUL4, 5-L          16,144
# left Locus ceruleus                                LC-L                  109
# left Magnocellular nucleus                         MA-L                1,047
# left Magnocellular reticular nucleus               MARN-L              1,119
# left Main olfactory bulb                           MOB-L             386,620
# left Mammillary body                               MBO-L               4,994
# left Medial accesory oculomotor nucleus            MA3-L                  45
# left Medial amygdalar nucleus                      MEA-L               9,591
# left Medial geniculate complex                     MG-L                2,184
# left Medial geniculate complex, dorsal part        MGd-L                 485
# left Medial geniculate complex, medial part        MGm-L                 688
# left Medial geniculate complex, ventral part       MGv-L               1,011
# left Medial group of the dorsal thalamus           MED-L               9,183
# left Medial habenula                               MH-L                1,392
# left Medial mammillary nucleus                     MM-L                2,437
# left Medial mammillary nucleus, dorsal part        MMd-L                 481
# left Medial mammillary nucleus, lateral part       MMl-L                 907
# left Medial mammillary nucleus, medial part        MMm-L                 545
# left Medial mammillary nucleus, median part        MMme-L                339
# left Medial mammillary nucleus, posterior part     MMp-L                 163
# left Medial preoptic area                          MPO-L               3,610
# left Medial preoptic nucleus                       MPN-L               2,382
# left Medial pretectal area                         MPT-L                 209
# left Medial septal complex                         MSC-L               4,735
# left Medial septal nucleus                         MS-L                1,913
# left Medial terminal nucleus of the accessory o... MT-L                   87
# left Medial vestibular nucleus                     MV-L                3,412
# left Median eminence                               ME-L                1,204
# left Median preoptic nucleus                       MEPO-L                466
# left Mediodorsal nucleus of thalamus               MD-L                5,799
# left Medulla                                       MY-L               87,766
# left Medulla, behavioral state related             MY-sat-L              719
# left Medulla, motor related                        MY-mot-L           41,765
# left Medulla, sensory related                      MY-sen-L           27,778
# left Medullary reticular nucleus                   MDRN-L              5,464
# left Medullary reticular nucleus, dorsal part      MDRNd-L             3,346
# left Medullary reticular nucleus, ventral part     MDRNv-L             2,118
# left Midbrain                                      MB-L              130,116
# left Midbrain raphe nuclei                         RAmb-L              2,562
# left Midbrain reticular nucleus                    MRN-L               7,917
# left Midbrain reticular nucleus, retrorubral area  RR-L                  290
# left Midbrain trigeminal nucleus                   MEV-L                  44
# left Midbrain, behavioral state related            MBsta-L             3,565
# left Midbrain, motor related                       MBmot-L            53,957
# left Midbrain, sensory related                     MBsen-L            53,531
# left Midline group of the dorsal thalamus          MTN-L              11,863
# left Motor nucleus of trigeminal                   V-L                   721
# left Nodulus (X)                                   NOD-L               9,427
# left Nucleus accumbens                             ACB-L              22,903
# left Nucleus ambiguus                              AMB-L                 113
# left Nucleus ambiguus, dorsal division             AMBd-L                 52
# left Nucleus ambiguus, ventral division            AMBv-L                 61
# left Nucleus incertus                              NI-L                  312
# left Nucleus of Darkschewitsch                     ND-L                  392
# left Nucleus of Roller                             NR-L                   92
# left Nucleus of reuniens                           RE-L                2,479
# left Nucleus of the brachium of the inferior co... NB-L                  298
# left Nucleus of the lateral lemniscus              NLL-L               1,420
# left Nucleus of the lateral olfactory tract        NLOT-L              2,449
# left Nucleus of the lateral olfactory tract, la... NLOT3-L               341
# left Nucleus of the lateral olfactory tract, mo... NLOT1-L               882
# left Nucleus of the lateral olfactory tract, py... NLOT2-L             1,224
# left Nucleus of the optic tract                    NOT-L               1,426
# left Nucleus of the posterior commissure           NPC-L               1,323
# left Nucleus of the solitary tract                 NTS-L               6,515
# left Nucleus of the trapezoid body                 NTB-L                 310
# left Nucleus prepositus                            PRP-L                 801
# left Nucleus raphe magnus                          RM-L                  221
# left Nucleus raphe obscurus                        RO-L                   66
# left Nucleus raphe pallidus                        RPA-L                 431
# left Nucleus raphe pontis                          RPO-L                 182
# left Nucleus sagulum                               SAG-L                  50
# left Nucleus x                                     x-L                   228
# left Nucleus y                                     y-L                    36
# left Oculomotor nucleus                            III-L                 101
# left Olfactory areas                               OLF-L             690,803
# left Olfactory tubercle                            OT-L               21,925
# left Olivary pretectal nucleus                     OP-L                  180
# left Orbital area                                  ORB-L              61,003
# left Orbital area, lateral part                    ORBl-L             27,073
# left Orbital area, lateral part, layer 1           ORBl1-L             2,278
# left Orbital area, lateral part, layer 2/3         ORBl2/3-L           7,114
# left Orbital area, lateral part, layer 5           ORBl5-L            13,447
# left Orbital area, lateral part, layer 6a          ORBl6a-L            3,980
# left Orbital area, lateral part, layer 6b          ORBl6b-L              252
# left Orbital area, medial part                     ORBm-L             14,307
# left Orbital area, medial part, layer 1            ORBm1-L             2,576
# left Orbital area, medial part, layer 2/3          ORBm2/3-L           3,979
# left Orbital area, medial part, layer 5            ORBm5-L             5,873
# left Orbital area, medial part, layer 6a           ORBm6a-L            1,860
# left Orbital area, medial part, layer 6b           ORBm6b-L               17
# left Orbital area, ventrolateral part              ORBvl-L            19,621
# left Orbital area, ventrolateral part, layer 1     ORBvl1-L            2,583
# left Orbital area, ventrolateral part, layer 2/3   ORBvl2/3-L          6,792
# left Orbital area, ventrolateral part, layer 5     ORBvl5-L            7,675
# left Orbital area, ventrolateral part, layer 6a    ORBvl6a-L           2,496
# left Orbital area, ventrolateral part, layer 6b    ORBvl6b-L              73
# left Pallidum                                      PAL-L              27,418
# left Pallidum, caudal region                       PALc-L              6,863
# left Pallidum, dorsal region                       PALd-L              2,503
# left Pallidum, medial region                       PALm-L              5,824
# left Pallidum, ventral region                      PALv-L              8,647
# left Parabigeminal nucleus                         PBG-L                  65
# left Parabrachial nucleus                          PB-L                3,549
# left Paracentral nucleus                           PCN-L                 837
# left Parafascicular nucleus                        PF-L                  968
# left Paraflocculus                                 PFL-L              35,684
# left Paragigantocellular reticular nucleus         PGRN-L              2,654
# left Paragigantocellular reticular nucleus, dor... PGRNd-L               442
# left Paragigantocellular reticular nucleus, lat... PGRNl-L             2,212
# left Paramedian lobule                             PRM-L              16,051
# left Paranigral nucleus                            PN-L                   46
# left Parapyramidal nucleus                         PPY-L                 218
# left Parasolitary nucleus                          PAS-L                 103
# left Parastrial nucleus                            PS-L                  885
# left Parasubiculum                                 PAR-L               5,035
# left Parasubthalamic nucleus                       PSTN-L                885
# left Parataenial nucleus                           PT-L                2,014
# left Paratrigeminal nucleus                        Pa5-L                 499
# left Paratrochlear nucleus                         Pa4-L                  30
# left Paraventricular hypothalamic nucleus          PVH-L               2,759
# left Paraventricular hypothalamic nucleus, desc... PVHd-L              1,006
# left Paraventricular nucleus of the thalamus       PVT-L               6,827
# left Parvicellular motor 5 nucleus                 PC5-L                 315
# left Parvicellular reticular nucleus               PARN-L              5,631
# left Pedunculopontine nucleus                      PPN-L                 876
# left Periaqueductal gray                           PAG-L              17,976
# left Perifornical nucleus                          PeF-L                 977
# left Perihypoglossal nuclei                        PHY-L                 894
# left Peripeduncular nucleus                        PP-L                  115
# left Perireunensis nucleus                         PR-L                  859
# left Perirhinal area                               PERI-L              6,850
# left Perirhinal area, layer 1                      PERI1-L             2,284
# left Perirhinal area, layer 2/3                    PERI2/3-L           2,982
# left Perirhinal area, layer 5                      PERI5-L             1,145
# left Perirhinal area, layer 6a                     PERI6a-L              375
# left Perirhinal area, layer 6b                     PERI6b-L               62
# left Peritrigeminal zone                           P5-L                  251
# left Periventricular hypothalamic nucleus, ante... PVa-L                 773
# left Periventricular hypothalamic nucleus, inte... PVi-L               1,806
# left Periventricular hypothalamic nucleus, post... PVp-L               1,414
# left Periventricular hypothalamic nucleus, preo... PVpo-L              1,933
# left Periventricular region                        PVR-L              21,128
# left Periventricular zone                          PVZ-L               8,656
# left Piriform area                                 PIR-L             110,747
# left Piriform-amygdalar area                       PAA-L               8,388
# left Pons                                          P-L                61,249
# left Pons, behavioral state related                P-sat-L             5,866
# left Pons, motor related                           P-mot-L            27,127
# left Pons, sensory related                         P-sen-L            10,903
# left Pontine central gray                          PCG-L               2,024
# left Pontine gray                                  PG-L               15,352
# left Pontine reticular nucleus                     PRNr-L              2,576
# left Pontine reticular nucleus, caudal part        PRNc-L              2,228
# left Posterior amygdalar nucleus                   PA-L                6,007
# left Posterior auditory area                       AUDpo-L             7,611
# left Posterior auditory area, layer 1              AUDpo1-L              999
# left Posterior auditory area, layer 2/3            AUDpo2/3-L          2,092
# left Posterior auditory area, layer 4              AUDpo4-L            1,448
# left Posterior auditory area, layer 5              AUDpo5-L            1,944
# left Posterior auditory area, layer 6a             AUDpo6a-L             873
# left Posterior auditory area, layer 6b             AUDpo6b-L             252
# left Posterior complex of the thalamus             PO-L                1,302
# left Posterior hypothalamic nucleus                PH-L                4,897
# left Posterior intralaminar thalamic nucleus       PIL-L                 400
# left Posterior limiting nucleus of the thalamus    POL-L                 565
# left Posterior parietal association areas          PTLp-L             30,635
# left Posterior pretectal nucleus                   PPT-L                 730
# left Posterior triangular thalamic nucleus         PoT-L                 691
# left Posterodorsal preoptic nucleus                PD-L                   73
# left Posterodorsal tegmental nucleus               PDTg-L                 57
# left Posterolateral visual area                    VISpl-L             5,801
# left Posterolateral visual area, layer 1           VISpl1-L            1,140
# left Posterolateral visual area, layer 2/3         VISpl2/3-L          1,446
# left Posterolateral visual area, layer 4           VISpl4-L              378
# left Posterolateral visual area, layer 5           VISpl5-L            2,015
# left Posterolateral visual area, layer 6a          VISpl6a-L             772
# left Posterolateral visual area, layer 6b          VISpl6b-L              48
# left Postpiriform transition area                  TR-L               10,485
# left Postrhinal area                               VISpor-L           14,029
# left Postrhinal area, layer 1                      VISpor1-L           2,704
# left Postrhinal area, layer 2/3                    VISpor2/3-L         4,343
# left Postrhinal area, layer 4                      VISpor4-L           1,037
# left Postrhinal area, layer 5                      VISpor5-L           3,980
# left Postrhinal area, layer 6a                     VISpor6a-L          1,737
# left Postrhinal area, layer 6b                     VISpor6b-L            226
# left Postsubiculum                                 POST-L              6,922
# left Precommissural nucleus                        PRC-L               1,139
# left Prelimbic area                                PL-L               24,537
# left Prelimbic area, layer 1                       PL1-L               3,236
# left Prelimbic area, layer 2/3                     PL2/3-L             4,847
# left Prelimbic area, layer 5                       PL5-L              12,785
# left Prelimbic area, layer 6a                      PL6a-L              3,613
# left Prelimbic area, layer 6b                      PL6b-L                 55
# left Preparasubthalamic nucleus                    PST-L                  71
# left Presubiculum                                  PRE-L               5,779
# left Pretectal region                              PRT-L               6,262
# left Primary auditory area                         AUDp-L             25,554
# left Primary auditory area, layer 1                AUDp1-L             3,522
# left Primary auditory area, layer 2/3              AUDp2/3-L           5,428
# left Primary auditory area, layer 4                AUDp4-L             4,090
# left Primary auditory area, layer 5                AUDp5-L             8,804
# left Primary auditory area, layer 6a               AUDp6a-L            2,951
# left Primary auditory area, layer 6b               AUDp6b-L              756
# left Primary motor area                            MOp-L             102,536
# left Primary motor area, Layer 1                   MOp1-L              8,546
# left Primary motor area, Layer 2/3                 MOp2/3-L           37,008
# left Primary motor area, Layer 5                   MOp5-L             33,955
# left Primary motor area, Layer 6a                  MOp6a-L            22,132
# left Primary motor area, Layer 6b                  MOp6b-L               893
# left Primary somatosensory area                    SSp-L             290,818
# left Primary somatosensory area, barrel field      SSp-bfd-L          77,233
# left Primary somatosensory area, barrel field, ... SSp-bfd1-L          9,392
# left Primary somatosensory area, barrel field, ... SSp-bfd2/3-L       15,410
# left Primary somatosensory area, barrel field, ... SSp-bfd4-L         19,442
# left Primary somatosensory area, barrel field, ... SSp-bfd5-L         14,727
# left Primary somatosensory area, barrel field, ... SSp-bfd6a-L        16,791
# left Primary somatosensory area, barrel field, ... SSp-bfd6b-L         1,469
# left Primary somatosensory area, lower limb        SSp-ll-L           19,882
# left Primary somatosensory area, lower limb, la... SSp-ll1-L           2,516
# left Primary somatosensory area, lower limb, la... SSp-ll2/3-L         5,595
# left Primary somatosensory area, lower limb, la... SSp-ll4-L           3,128
# left Primary somatosensory area, lower limb, la... SSp-ll5-L           4,477
# left Primary somatosensory area, lower limb, la... SSp-ll6a-L          3,859
# left Primary somatosensory area, lower limb, la... SSp-ll6b-L            304
# left Primary somatosensory area, mouth             SSp-m-L            83,560
# left Primary somatosensory area, mouth, layer 1    SSp-m1-L            7,699
# left Primary somatosensory area, mouth, layer 2/3  SSp-m2/3-L         21,780
# left Primary somatosensory area, mouth, layer 4    SSp-m4-L           17,010
# left Primary somatosensory area, mouth, layer 5    SSp-m5-L           14,878
# left Primary somatosensory area, mouth, layer 6a   SSp-m6a-L          21,489
# left Primary somatosensory area, mouth, layer 6b   SSp-m6b-L             701
# left Primary somatosensory area, nose              SSp-n-L            39,145
# left Primary somatosensory area, nose, layer 1     SSp-n1-L            4,245
# left Primary somatosensory area, nose, layer 2/3   SSp-n2/3-L          7,513
# left Primary somatosensory area, nose, layer 4     SSp-n4-L            8,682
# left Primary somatosensory area, nose, layer 5     SSp-n5-L            7,677
# left Primary somatosensory area, nose, layer 6a    SSp-n6a-L          10,639
# left Primary somatosensory area, nose, layer 6b    SSp-n6b-L             388
# left Primary somatosensory area, trunk             SSp-tr-L           13,114
# left Primary somatosensory area, trunk, layer 1    SSp-tr1-L           1,445
# left Primary somatosensory area, trunk, layer 2/3  SSp-tr2/3-L         3,432
# left Primary somatosensory area, trunk, layer 4    SSp-tr4-L           2,075
# left Primary somatosensory area, trunk, layer 5    SSp-tr5-L           3,542
# left Primary somatosensory area, trunk, layer 6a   SSp-tr6a-L          2,314
# left Primary somatosensory area, trunk, layer 6b   SSp-tr6b-L            303
# left Primary somatosensory area, unassigned        SSp-un-L           15,208
# left Primary somatosensory area, unassigned, la... SSp-un1-L           1,676
# left Primary somatosensory area, unassigned, la... SSp-un2/3-L         4,136
# left Primary somatosensory area, unassigned, la... SSp-un4-L           2,934
# left Primary somatosensory area, unassigned, la... SSp-un5-L           2,979
# left Primary somatosensory area, unassigned, la... SSp-un6a-L          3,324
# left Primary somatosensory area, unassigned, la... SSp-un6b-L            156
# left Primary somatosensory area, upper limb        SSp-ul-L           42,675
# left Primary somatosensory area, upper limb, la... SSp-ul1-L           4,943
# left Primary somatosensory area, upper limb, la... SSp-ul2/3-L        12,767
# left Primary somatosensory area, upper limb, la... SSp-ul4-L           8,098
# left Primary somatosensory area, upper limb, la... SSp-ul5-L           8,137
# left Primary somatosensory area, upper limb, la... SSp-ul6a-L          8,366
# left Primary somatosensory area, upper limb, la... SSp-ul6b-L            362
# left Primary visual area                           VISp-L            113,337
# left Primary visual area, layer 1                  VISp1-L            12,017
# left Primary visual area, layer 2/3                VISp2/3-L          35,916
# left Primary visual area, layer 4                  VISp4-L            23,929
# left Primary visual area, layer 5                  VISp5-L            23,115
# left Primary visual area, layer 6a                 VISp6a-L           16,293
# left Primary visual area, layer 6b                 VISp6b-L            2,065
# left Principal sensory nucleus of the trigeminal   PSV-L               1,971
# left Prosubiculum                                  ProS-L              6,459
# left Pyramus (VIII)                                PYR-L               6,267
# left Red nucleus                                   RN-L                  853
# left Reticular nucleus of the thalamus             RT-L                3,035
# left Retrochiasmatic area                          RCH-L                 563
# left Retrohippocampal region                       RHP-L             134,573
# left Retroparafascicular nucleus                   RPF-L                 177
# left Retrosplenial area                            RSP-L              96,319
# left Retrosplenial area, dorsal part               RSPd-L             34,040
# left Retrosplenial area, dorsal part, layer 1      RSPd1-L             5,504
# left Retrosplenial area, dorsal part, layer 2/3    RSPd2/3-L          10,396
# left Retrosplenial area, dorsal part, layer 5      RSPd5-L            12,592
# left Retrosplenial area, dorsal part, layer 6a     RSPd6a-L            5,354
# left Retrosplenial area, dorsal part, layer 6b     RSPd6b-L              191
# left Retrosplenial area, lateral agranular part    RSPagl-L           23,912
# left Retrosplenial area, lateral agranular part... RSPagl1-L           3,773
# left Retrosplenial area, lateral agranular part... RSPagl2/3-L         7,231
# left Retrosplenial area, lateral agranular part... RSPagl5-L           8,752
# left Retrosplenial area, lateral agranular part... RSPagl6a-L          3,850
# left Retrosplenial area, lateral agranular part... RSPagl6b-L            304
# left Retrosplenial area, ventral part              RSPv-L             38,366
# left Retrosplenial area, ventral part, layer 1     RSPv1-L             6,426
# left Retrosplenial area, ventral part, layer 2/3   RSPv2/3-L          13,665
# left Retrosplenial area, ventral part, layer 5     RSPv5-L            14,965
# left Retrosplenial area, ventral part, layer 6a    RSPv6a-L            3,121
# left Retrosplenial area, ventral part, layer 6b    RSPv6b-L              188
# left Rhomboid nucleus                              RH-L                  632
# left Rostral linear nucleus raphe                  RL-L                  276
# left Rostrolateral area, layer 1                   VISrl1-L            1,573
# left Rostrolateral area, layer 2/3                 VISrl2/3-L          3,505
# left Rostrolateral area, layer 4                   VISrl4-L            2,998
# left Rostrolateral area, layer 5                   VISrl5-L            3,808
# left Rostrolateral area, layer 6a                  VISrl6a-L           2,285
# left Rostrolateral area, layer 6b                  VISrl6b-L             444
# left Rostrolateral visual area                     VISrl-L            14,615
# left Secondary motor area                          MOs-L             100,705
# left Secondary motor area, layer 1                 MOs1-L             14,809
# left Secondary motor area, layer 2/3               MOs2/3-L           29,666
# left Secondary motor area, layer 5                 MOs5-L             39,059
# ...
# right Tegmental reticular nucleus                  TRN-R                        15,696
# right Temporal association areas                   TEa-R                        16,889
# right Temporal association areas, layer 1          TEa1-R                       16,457
# right Temporal association areas, layer 2/3        TEa2/3-R                     17,541
# right Temporal association areas, layer 4          TEa4-R                       18,730
# right Temporal association areas, layer 5          TEa5-R                       15,903
# right Temporal association areas, layer 6a         TEa6a-R                      17,976
# right Temporal association areas, layer 6b         TEa6b-R                      11,878
# right Thalamus                                     TH-R                          4,744
# right Thalamus, polymodal association cortex re... DORpm-R                       5,534
# right Thalamus, sensory-motor cortex related       DORsm-R                       3,160
# right Triangular nucleus of septum                 TRS-R                         4,947
# right Trochlear nucleus                            IV-R                          9,430
# right Tuberal nucleus                              TU-R                          6,870
# right Tuberomammillary nucleus                     TM-R                         11,156
# right Tuberomammillary nucleus, dorsal part        TMd-R                        18,803
# right Tuberomammillary nucleus, ventral part       TMv-R                         8,652
# right Uvula (IX)                                   UVU-R                         6,890
# right Vascular organ of the lamina terminalis      OV-R                         36,186
# right Ventral anterior-lateral complex of the t... VAL-R                         1,349
# right Ventral auditory area                        AUDv-R                       15,918
# right Ventral auditory area, layer 1               AUDv1-R                      13,041
# right Ventral auditory area, layer 2/3             AUDv2/3-R                    14,397
# right Ventral auditory area, layer 4               AUDv4-R                      21,229
# right Ventral auditory area, layer 5               AUDv5-R                      16,313
# right Ventral auditory area, layer 6a              AUDv6a-R                     16,556
# right Ventral auditory area, layer 6b              AUDv6b-R                     12,827
# right Ventral cochlear nucleus                     VCO-R                         7,196
# right Ventral group of the dorsal thalamus         VENT-R                        2,430
# right Ventral medial nucleus of the thalamus       VM-R                          2,745
# right Ventral part of the lateral geniculate co... LGv-R                        12,441
# right Ventral posterior complex of the thalamus    VP-R                          2,526
# right Ventral posterolateral nucleus of the tha... VPL-R                         2,061
# right Ventral posterolateral nucleus of the tha... VPLpc-R                       2,552
# right Ventral posteromedial nucleus of the thal... VPM-R                         2,712
# right Ventral posteromedial nucleus of the thal... VPMpc-R                       2,982
# right Ventral premammillary nucleus                PMv-R                         8,007
# right Ventral tegmental area                       VTA-R                         1,983
# right Ventral tegmental nucleus                    VTN-R                         1,457
# right Ventrolateral preoptic nucleus               VLPO-R                       18,263
# right Ventromedial hypothalamic nucleus            VMH-R                         6,909
# right Ventromedial preoptic nucleus                VMPO-R                       28,499
# right Vermal regions                               VERM-R                        3,238
# right Vestibular nuclei                            VNC-R                         2,603
# right Vestibulocerebellar nucleus                  VeCB-R                        1,983
# right Visceral area                                VISC-R                       13,331
# right Visceral area, layer 1                       VISC1-R                      14,169
# right Visceral area, layer 2/3                     VISC2/3-R                    12,200
# right Visceral area, layer 4                       VISC4-R                      16,690
# right Visceral area, layer 5                       VISC5-R                      14,214
# right Visceral area, layer 6a                      VISC6a-R                     12,148
# right Visceral area, layer 6b                      VISC6b-R                      8,113
# right Visual areas                                 VIS-R                        16,434
# right Xiphoid thalamic nucleus                     Xi-R                         13,225
# right Zona incerta                                 ZI-R                          4,296
# right alveus                                       alv-R                         4,703
# right amygdalar capsule                            amc-R                         7,687
# right anterior commissure, olfactory limb          aco-R                         4,799
# right anterior commissure, temporal limb           act-R                         3,882
# right arbor vitae                                  arb-R                         1,908
# right auditory radiation                           ar-R                          5,853
# right brachium of the inferior colliculus          bic-R                         7,035
# right brachium of the superior colliculus          bsc-R                         5,299
# right central canal, spinal cord/medulla           c-R                           7,466
# right cerebal peduncle                             cpd-R                         1,870
# right cerebellar commissure                        cbc-R                         1,280
# right cerebellar peduncles                         cbp-R                         4,689
# right cerebellum related fiber tracts              cbf-R                         2,703
# right cerebral aqueduct                            AQ-R                         12,606
# right cerebral nuclei related                      epsc-R                        3,743
# right cerebrum related                             mfbc-R                        4,840
# right cervicothalamic tract                        cett-R                        6,194
# right choroid plexus                               chpl-R                       14,195
# right cingulum bundle                              cing-R                        6,914
# right cochlear nerve                               cVIIIn-R                      6,231
# right columns of the fornix                        fx-R                          5,448
# right commissural branch of stria terminalis       stc-R                         7,861
# right corpus callosum                              cc-R                          3,966
# right corpus callosum, anterior forceps            fa-R                          4,169
# right corpus callosum, body                        ccb-R                         4,214
# right corpus callosum, extreme capsule             ee-R                         11,975
# right corpus callosum, posterior forceps           fp-R                          3,458
# right corpus callosum, splenium                    ccs-R                         3,574
# right corticospinal tract                          cst-R                         2,847
# right cranial nerves                               cm-R                          9,948
# right crossed tectospinal pathway                  tspc-R                        2,544
# right cuneate fascicle                             cuf-R                         4,965
# right direct tectospinal pathway                   tspd-R                       10,666
# right doral tegmental decussation                  dtd-R                         7,017
# right dorsal acoustic stria                        das-R                           881
# right dorsal column                                dc-R                          4,965
# right dorsal fornix                                df-R                          1,552
# right dorsal hippocampal commissure                dhc-R                         1,691
# right dorsal limb                                  lotd-R                       21,004
# right dorsal roots                                 drt-R                         6,194
# right dorsal spinocerebellar tract                 sctd-R                        1,187
# right epithalamus related                          mfbse-R                       4,576
# right external capsule                             ec-R                          5,899
# right external medullary lamina of the thalamus    em-R                          2,583
# right extrapyramidal fiber systems                 eps-R                         4,210
# right facial nerve                                 VIIn-R                        1,782
# right fasciculus retroflexus                       fr-R                          2,530
# right fiber tracts                                 fiber tracts-R                5,575
# right fimbria                                      fi-R                          5,456
# right fornix system                                fxs-R                         4,275
# right fourth ventricle                             V4-R                         10,711
# right genu of corpus callosum                      ccg-R                         2,923
# right genu of the facial nerve                     gVIIn-R                       3,027
# right habenular commissure                         hbc-R                        13,853
# right hippocampal commissures                      hc-R                          1,671
# right hypothalamus related                         mfsbshy-R                     4,677
# right inferior cerebellar peduncle                 icp-R                         3,742
# right inferior colliculus commissure               cic-R                         2,671
# right internal capsule                             int-R                         1,424
# right lateral forebrain bundle system              lfbs-R                        3,992
# right lateral lemniscus                            ll-R                          4,630
# right lateral olfactory tract, body                lot-R                        12,345
# right lateral olfactory tract, general             lotg-R                       13,625
# right lateral recess                               V4r-R                        12,288
# right lateral ventricle                            VL-R                         11,542
# right mammillary peduncle                          mp-R                          2,160
# right mammillary related                           mfbsma-R                      4,279
# right mammillotegmental tract                      mtg-R                         5,985
# right mammillothalamic tract                       mtt-R                         3,646
# right medial corticohypothalamic tract             mct-R                        12,416
# right medial forebrain bundle                      mfb-R                         5,700
# right medial forebrain bundle system               mfbs-R                        4,821
# right medial lemniscus                             ml-R                          6,235
# right medial longitudinal fascicle                 mlf-R                         4,992
# right middle cerebellar peduncle                   mcp-R                         7,294
# right motor root of the trigeminal nerve           moV-R                         9,966
# right nigrostriatal tract                          nst-R                         3,743
# right oculomotor nerve                             IIIn-R                        5,335
# right olfactory nerve                              In-R                         13,603
# right olfactory nerve layer of main olfactory bulb onl-R                        15,211
# right optic chiasm                                 och-R                        12,967
# right optic nerve                                  IIn-R                         7,369
# right optic radiation                              or-R                          6,058
# right optic tract                                  opt-R                         5,149
# right postcommissural fornix                       fxpo-R                        5,649
# right posterior commissure                         pc-R                          6,810
# right posteromedial visual area                    VISpm-R                      17,949
# right posteromedial visual area, layer 1           VISpm1-R                     10,398
# right posteromedial visual area, layer 2/3         VISpm2/3-R                   20,317
# right posteromedial visual area, layer 4           VISpm4-R                     28,128
# right posteromedial visual area, layer 5           VISpm5-R                     16,824
# right posteromedial visual area, layer 6a          VISpm6a-R                    18,747
# right posteromedial visual area, layer 6b          VISpm6b-R                    15,356
# right principal mammillary tract                   pm-R                          5,412
# right pyramid                                      py-R                          7,086
# right pyramidal decussation                        pyd-R                         9,662
# right root                                         root-R                        9,255
# right rubrospinal tract                            rust-R                        5,656
# right sensory root of the trigeminal nerve         sV-R                          6,936
# right solitary tract                               ts-R                          7,670
# right spinal tract of the trigeminal nerve         sptV-R                        5,532
# right stria medullaris                             sm-R                          4,199
# right stria terminalis                             st-R                          3,414
# right subependymal zone                            SEZ-R                         6,523
# right superior cerebelar peduncles                 scp-R                         2,341
# right superior cerebellar peduncle decussation     dscp-R                        3,055
# right superior colliculus commissure               csc-R                         6,206
# right supra-callosal cerebral white matter         scwm-R                        7,056
# right supraoptic commissures                       sup-R                         8,607
# right tectospinal pathway                          tsp-R                         2,607
# right thalamus related                             lfbst-R                       5,860
# right third ventricle                              V3-R                         15,933
# right trapezoid body                               tb-R                         10,429
# right trigeminal nerve                             Vn-R                          7,012
# right trochlear nerve                              IVn-R                         5,569
# right uncinate fascicle                            uf-R                          2,601
# right vagus nerve                                  Xn-R                          7,670
# right ventral hippocampal commissure               vhc-R                         1,376
# right ventral spinocerebellar tract                sctv-R                        2,268
# right ventral tegmental decussation                vtd-R                         5,886
# right ventricular systems                          VS-R                         12,161
# right vestibular nerve                             vVIIIn-R                      2,722
# right vestibulocochlear nerve                      VIIIn-R                       5,702
# right vomeronasal nerve                            von-R                        14,988

# %%
import pandas as pd
import glob

# Create empty DataFrames for each group
fed_df = pd.DataFrame(columns=['count', 'density (cells/mm^3)'])
fastrefeed_df = pd.DataFrame(columns=['count', 'density (cells/mm^3)'])
restraint_df = pd.DataFrame(columns=['count', 'density (cells/mm^3)'])

# Loop through all CSV files in the current directory
for file in glob.glob("*.csv"):
    # Load the CSV into a DataFrame
    df = pd.read_csv(file)
    
    # Select only the relevant columns
    df = df[['count', 'density (cells/mm^3)']]
    
    # Determine which group the data belongs to and concatenate it accordingly
    if 'Fed' in file:
        fed_df = pd.concat([fed_df, df], axis=0)
    elif 'FastRefeed' in file:
        fastrefeed_df = pd.concat([fastrefeed_df, df], axis=0)
    elif 'Restraint' in file:
        restraint_df = pd.concat([restraint_df, df], axis=0)
    else:
        print(f"Warning: {file} does not match any group.")

# Take the mean of each group
fed_mean = fed_df.mean()
fastrefeed_mean = fastrefeed_df.mean()
restraint_mean = restraint_df.mean()

# Combine the mean values into a single DataFrame
grouped_means_df = pd.concat([fed_mean, fastrefeed_mean, restraint_mean], axis=1, keys=['Fed', 'FastRefeed', 'Restraint'])

# Format the DataFrame to show integers with commas for thousands separators
grouped_means_df = grouped_means_df.applymap(lambda x: "{:,}".format(int(x)))

# Display the DataFrame
print(grouped_means_df)
# Out:
#                          Fed FastRefeed Restraint
# count                 18,817     31,725    28,195
# density (cells/mm^3)   7,601     13,666    13,372

# %%
# Sort the dataframes by count and density values and select top 20 rows
fed_top_20 = fed_df.sort_values(by=['count', 'density (cells/mm^3)'], ascending=False).head(20)
fastrefeed_top_20 = fastrefeed_df.sort_values(by=['count', 'density (cells/mm^3)'], ascending=False).head(20)
restraint_top_20 = restraint_df.sort_values(by=['count', 'density (cells/mm^3)'], ascending=False).head(20)

# Format the dataframes to show integers with commas for thousands separators
fed_top_20 = fed_top_20.applymap(lambda x: "{:,}".format(int(x)))
fastrefeed_top_20 = fastrefeed_top_20.applymap(lambda x: "{:,}".format(int(x)))
restraint_top_20 = restraint_top_20.applymap(lambda x: "{:,}".format(int(x)))

# Display the top 20 areas for each group
print("Top 20 areas for Fed group:")
print(fed_top_20)
print()

print("Top 20 areas for FastRefeed group:")
print(fastrefeed_top_20)
print()

print("Top 20 areas for Restraint group:")
print(restraint_top_20)
# Out:
# Top 20 areas for Fed group:
#          count density (cells/mm^3)
# 1    3,091,451               12,317
# 2    2,902,221               12,922
# 3    2,350,993               17,049
# 4    2,211,795               19,970
# 5    2,169,126               20,405
# 1    2,142,225                8,535
# 2    2,028,564                9,032
# 839  1,694,726                6,690
# 3    1,690,543               12,259
# 4    1,582,934               14,292
# 840  1,572,739                6,989
# 5    1,560,228               14,677
# 6    1,370,653               22,240
# 841  1,233,696                8,940
# 842  1,151,421               10,392
# 843  1,118,691               10,519
# 839  1,089,909                4,302
# 840  1,016,109                4,515
# 6      853,076               13,842
# 841    794,915                5,760
#
# Top 20 areas for FastRefeed group:
#          count density (cells/mm^3)
# 1    4,088,794               16,290
# 839  3,895,260               15,378
# 2    3,821,572               17,015
# 1    3,802,646               15,150
# 2    3,551,289               15,812
# 840  3,541,645               15,740
# 3    2,996,598               21,731
# 841  2,803,853               20,320
# 3    2,787,185               20,212
# 4    2,735,851               24,702
# 5    2,659,553               25,019
# 842  2,556,308               23,072
# 4    2,508,292               22,647
# 843  2,495,059               23,462
# 5    2,441,469               22,967
# 839  1,738,855                6,864
# 6    1,641,426               26,634
# 840  1,633,325                7,258
# 6    1,571,725               25,503
# 844  1,507,403               24,443
#
# Top 20 areas for Restraint group:
#          count density (cells/mm^3)
# 839  3,744,577               14,783
# 1    3,519,593               14,023
# 840  3,469,478               15,419
# 2    3,257,448               14,503
# 1    3,057,866               12,183
# 841  2,903,096               21,039
# 2    2,831,394               12,606
# 842  2,657,789               23,988
# 843  2,603,037               24,477
# 3    2,588,307               18,770
# 4    2,365,780               21,360
# 5    2,305,744               21,690
# 3    2,179,357               15,804
# 4    1,991,062               17,977
# 5    1,940,489               18,254
# 839  1,902,621                7,511
# 840  1,726,607                7,673
# 844  1,421,620               23,052
# 841  1,291,307                9,358
# 6    1,265,495               20,534
